# %%
import os
import pandas as pd
import numpy as np

# %%
subs = pd.read_csv('subscriptions.txt',sep = "\s+", index_col = None, parse_dates=['RenewalDate', 'PaymentDate'])

# %%
subs.head()
# Out:
#    SubscriptionID  CustomerID  ProductID    Pattern   StartDate     EndDate  \
# 0         1000024     1150045        8.0  1111110.0  18/01/2010  17/04/2010
# 1         1000082     1150046        8.0  1111110.0  14/01/2010  12/03/2010
# 2          100012       89085        8.0  1111110.0   1/01/2008  30/12/2008
# 3          100013       89085        8.0  1111110.0   2/01/2007  31/12/2007
# 4          100016       89087        8.0  1111110.0   1/01/2008  30/12/2008
#
#    NbrNewspapers NbrStart RenewalDate PaymentType     ...     PaymentDate  \
# 0           76.0       25  17/03/2010          BT     ...      27/01/2010
# 1           50.0       25   3/03/2010          BT     ...      11/02/2010
# 2          304.0       10  21/11/2008          BT     ...      12/12/2007
# 3          304.0       25   1/12/2007          BT     ...      28/12/2006
# 4          304.0       10  21/11/2008          BT     ...      12/12/2007
#
# ...

# %%
subs[subs.PaymentStatus=='Not']
# Out:
#        SubscriptionID  CustomerID  ProductID    Pattern   StartDate  \
# 523           1029653      850336        2.0  1111110.0  26/03/2010
# 530           1030202      675064        5.0  1111110.0  27/03/2010
# 801           1049260      302264        8.0  1111110.0  22/04/2010
# 913           1055662       28962        8.0  1111110.0  29/03/2010
# 954           1058687       76760        8.0  1111110.0  27/04/2010
# 1029          1068794      890162        2.0  1111110.0   4/05/2010
# 1062          1071314      904175        6.0  1111110.0   7/05/2010
# 1282          1083945       65202        8.0  1111110.0  21/04/2010
# 1498          1099521      999215        8.0  1111110.0  10/06/2010
# 1616          1107281      307133        6.0  1111110.0  24/06/2010
# 1766          1119293      928227        5.0  1111110.0   9/07/2010
# 1777          1121330     1105350        8.0       10.0   4/07/2010
# 1875          1129556      829226        8.0  1111110.0  14/07/2010
# ...
